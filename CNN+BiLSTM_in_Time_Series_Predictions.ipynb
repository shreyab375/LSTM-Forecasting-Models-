# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyab375/LSTM-Forecasting-Models-/blob/main/CNN%2BBiLSTM_in_Time_Series_Predictions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import joblib
import pandas as pd
import datetime
import tensorflow as tf
import os
import random
import timeit
import seaborn as sns
import datetime
import matplotlib.pyplot as plt

import tensorflow_probability as tfp
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, MaxPooling1D, Bidirectional, Dropout
from tensorflow.keras import backend as K
from tensorflow.keras.metrics import RootMeanSquaredError

# %%
#Reade the data
df_sn=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/snv1_full.csv', sep=",", header=0)
#convert the date to datetime format
df_sn.Date = pd.to_datetime(df_sn.Date)

# %%
#Select the values from 1900 to avoid any data gaps
df_sn = df_sn.set_index('Date')
df_sn = df_sn.truncate(before = '1900-01-01', after ='2024-01-01')
df_sn = df_sn.reset_index()

# %%
#Step 3
# Split the data into training, validation, and test sets
n = len(df_sn)
n_train = int(0.8 * n)
n_val = int(0.1 * n)
n_test = n - n_train - n_val

train_data = df_sn[:n_train].drop(columns='Date').values
train_date = df_sn[:n_train].drop(columns=['Sn'])

val_data   = df_sn[n_train:n_train+n_val].drop(columns='Date').values
val_date   = df_sn[n_train:n_train+n_val].drop(columns=['Sn'])

test_data  = df_sn[-n_test:].drop(columns=['Date']).values
test_date  = df_sn[-n_test:].drop(columns=['Sn'])

# %%
print('Train Set      : ',len(train_data))
print('Validation Set : ',len(val_data))
print('Test Set       : ',len(test_data))
# Out:
# Train Set      :  33723
# Validation Set :  4215
# Test Set       :  4216

# %%
#Step 4
# Normalize the data using StandardScaler
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
train_data = scaler.fit_transform(train_data)
val_data   = scaler.transform(val_data)
test_data  = scaler.transform(test_data)

# %%
#Step 5
# Prediction intervals
ten_days = 10
hundred_days = 100
one_year = 365
ten_years = 3650

# Prepare the datasets
ten_day_date = test_date.head(ten_days)
ten_day_data = test_data[:ten_days]

hundred_day_date = test_date.head(hundred_days)
hundred_day_data = test_data[:hundred_days]

one_year_date = test_date.head(one_year)
one_year_data = test_data[:one_year]

ten_year_date = test_date.head(ten_years)
ten_year_data = test_data[:ten_years]

# %%
#Step 6
#Create a windowed dataset for training
# Assume test_data is your feature (e.g., SN) and is a numpy array
def reshape_data(data, time_steps):
    X = []
    y = []
    for i in range(len(data) - time_steps):
        X.append(data[i:(i + time_steps)])
        y.append(data[i + time_steps])
    X = np.array(X)
    y = np.array(y)
    return X, y

# %%
#Step 7
#Let's create a time step of 10 days
## Example: Predict for 10 days (using 10 days history to predict the next day)
time_steps = 10
X_train, y_train = reshape_data(train_data, time_steps)
X_val, y_val     = reshape_data(val_data, time_steps)
X_test, y_test   = reshape_data(test_data, time_steps)

# %%
#Step 8
def cc(y_true, y_pred):
    """
    Compute the correlation coefficient between y_true and y_pred.
    """
    # Compute the covariance matrix
    cov = tfp.stats.covariance(y_true, y_pred, sample_axis=0)

    # Compute the standard deviation of y_true and y_pred
    std_true = K.std(y_true)
    std_pred = K.std(y_pred)

    # Compute the correlation coefficient
    return cov / (std_true * std_pred)

# %%
input_shape = (time_steps, 1)

model = Sequential([
    Conv1D(filters=8, kernel_size=1, activation='relu', input_shape=input_shape),
    Conv1D(filters=8, kernel_size=1, activation='relu'),
    MaxPooling1D(pool_size=2),

    Bidirectional(LSTM(64, return_sequences=True)),
    Dropout(0.5),
    Bidirectional(LSTM(64)),

    Dense(32, activation='relu'),
    Dense(1)
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
model.compile(optimizer= optimizer,
              loss=tf.keras.losses.Huber(),
              metrics= [RootMeanSquaredError(), cc])

# %%
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss',
                               patience=5, verbose=1,
                               mode='min',
                               restore_best_weights=True)

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=16,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 40s 15ms/step - cc: nan - loss: 0.1812 - root_mean_squared_error: 0.6278 - val_cc: nan - val_loss: 0.0687 - val_root_mean_squared_error: 0.3721
# Epoch 2/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 22s 10ms/step - cc: nan - loss: 0.0798 - root_mean_squared_error: 0.4038 - val_cc: nan - val_loss: 0.0523 - val_root_mean_squared_error: 0.3240
# Epoch 3/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 43s 11ms/step - cc: nan - loss: 0.0656 - root_mean_squared_error: 0.3651 - val_cc: nan - val_loss: 0.0500 - val_root_mean_squared_error: 0.3168
# Epoch 4/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - cc: nan - loss: 0.0623 - root_mean_squared_error: 0.3554 - val_cc: nan - val_loss: 0.0486 - val_root_mean_squared_error: 0.3123
# Epoch 5/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - cc: nan - loss: 0.0585 - root_mean_squared_error: 0.3436 - val_cc: nan - val_loss: 0.0446 - val_root_mean_squared_error: 0.2989
# Epoch 6/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - cc: nan - loss: 0.0555 - root_mean_squared_error: 0.3349 - val_cc: nan - val_loss: 0.0514 - val_root_mean_squared_error: 0.3210
# Epoch 7/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - cc: nan - loss: 0.0563 - root_mean_squared_error: 0.3369 - val_cc: nan - val_loss: 0.0410 - val_root_mean_squared_error: 0.2864
# Epoch 8/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - cc: nan - loss: 0.0530 - root_mean_squared_error: 0.3268 - val_cc: nan - val_loss: 0.0393 - val_root_mean_squared_error: 0.2804
# Epoch 9/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - cc: nan - loss: 0.0522 - root_mean_squared_error: 0.3243 - val_cc: nan - val_loss: 0.0383 - val_root_mean_squared_error: 0.2767
# Epoch 10/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - cc: nan - loss: 0.0501 - root_mean_squared_error: 0.3175 - val_cc: nan - val_loss: 0.0374 - val_root_mean_squared_error: 0.2736
# Epoch 11/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - cc: nan - loss: 0.0496 - root_mean_squared_error: 0.3161 - val_cc: nan - val_loss: 0.0556 - val_root_mean_squared_error: 0.3339
# Epoch 12/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 19s 8ms/step - cc: nan - loss: 0.0496 - root_mean_squared_error: 0.3163 - val_cc: nan - val_loss: 0.0343 - val_root_mean_squared_error: 0.2619
# Epoch 13/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - cc: nan - loss: 0.0482 - root_mean_squared_error: 0.3115 - val_cc: nan - val_loss: 0.0416 - val_root_mean_squared_error: 0.2884
# Epoch 14/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 19s 8ms/step - cc: nan - loss: 0.0467 - root_mean_squared_error: 0.3067 - val_cc: nan - val_loss: 0.0327 - val_root_mean_squared_error: 0.2558
# Epoch 15/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - cc: nan - loss: 0.0453 - root_mean_squared_error: 0.3020 - val_cc: nan - val_loss: 0.0317 - val_root_mean_squared_error: 0.2518
# Epoch 16/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - cc: nan - loss: 0.0452 - root_mean_squared_error: 0.3017 - val_cc: nan - val_loss: 0.0311 - val_root_mean_squared_error: 0.2496
# Epoch 17/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - cc: nan - loss: 0.0443 - root_mean_squared_error: 0.2985 - val_cc: nan - val_loss: 0.0305 - val_root_mean_squared_error: 0.2470
# Epoch 18/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - cc: nan - loss: 0.0446 - root_mean_squared_error: 0.2995 - val_cc: nan - val_loss: 0.0301 - val_root_mean_squared_error: 0.2456
# Epoch 19/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - cc: nan - loss: 0.0432 - root_mean_squared_error: 0.2946 - val_cc: nan - val_loss: 0.0312 - val_root_mean_squared_error: 0.2497
# Epoch 20/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - cc: nan - loss: 0.0432 - root_mean_squared_error: 0.2947 - val_cc: nan - val_loss: 0.0305 - val_root_mean_squared_error: 0.2468
# Epoch 21/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - cc: nan - loss: 0.0427 - root_mean_squared_error: 0.2933 - val_cc: nan - val_loss: 0.0293 - val_root_mean_squared_error: 0.2419
# Epoch 22/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - cc: nan - loss: 0.0427 - root_mean_squared_error: 0.2928 - val_cc: nan - val_loss: 0.0329 - val_root_mean_squared_error: 0.2565
# Epoch 23/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - cc: nan - loss: 0.0426 - root_mean_squared_error: 0.2928 - val_cc: nan - val_loss: 0.0311 - val_root_mean_squared_error: 0.2494
# Epoch 24/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 19s 8ms/step - cc: nan - loss: 0.0413 - root_mean_squared_error: 0.2881 - val_cc: nan - val_loss: 0.0287 - val_root_mean_squared_error: 0.2397
# Epoch 25/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - cc: nan - loss: 0.0417 - root_mean_squared_error: 0.2895 - val_cc: nan - val_loss: 0.0290 - val_root_mean_squared_error: 0.2407
# Epoch 26/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - cc: nan - loss: 0.0416 - root_mean_squared_error: 0.2891 - val_cc: nan - val_loss: 0.0285 - val_root_mean_squared_error: 0.2389
# Epoch 27/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 19s 8ms/step - cc: nan - loss: 0.0408 - root_mean_squared_error: 0.2864 - val_cc: nan - val_loss: 0.0305 - val_root_mean_squared_error: 0.2469
# Epoch 28/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - cc: nan - loss: 0.0409 - root_mean_squared_error: 0.2866 - val_cc: nan - val_loss: 0.0280 - val_root_mean_squared_error: 0.2365
# Epoch 29/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - cc: nan - loss: 0.0403 - root_mean_squared_error: 0.2847 - val_cc: nan - val_loss: 0.0280 - val_root_mean_squared_error: 0.2368
# Epoch 30/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - cc: nan - loss: 0.0412 - root_mean_squared_error: 0.2881 - val_cc: nan - val_loss: 0.0289 - val_root_mean_squared_error: 0.2404
# Epoch 31/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 19s 8ms/step - cc: nan - loss: 0.0406 - root_mean_squared_error: 0.2858 - val_cc: nan - val_loss: 0.0304 - val_root_mean_squared_error: 0.2464
# Epoch 32/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - cc: nan - loss: 0.0404 - root_mean_squared_error: 0.2852 - val_cc: nan - val_loss: 0.0388 - val_root_mean_squared_error: 0.2785
# Epoch 33/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - cc: nan - loss: 0.0410 - root_mean_squared_error: 0.2869 - val_cc: nan - val_loss: 0.0276 - val_root_mean_squared_error: 0.2350
# Epoch 34/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - cc: nan - loss: 0.0392 - root_mean_squared_error: 0.2806 - val_cc: nan - val_loss: 0.0290 - val_root_mean_squared_error: 0.2407
# Epoch 35/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - cc: nan - loss: 0.0396 - root_mean_squared_error: 0.2817 - val_cc: nan - val_loss: 0.0275 - val_root_mean_squared_error: 0.2344
# Epoch 36/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - cc: nan - loss: 0.0402 - root_mean_squared_error: 0.2843 - val_cc: nan - val_loss: 0.0320 - val_root_mean_squared_error: 0.2528
# Epoch 37/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - cc: nan - loss: 0.0403 - root_mean_squared_error: 0.2844 - val_cc: nan - val_loss: 0.0273 - val_root_mean_squared_error: 0.2339
# Epoch 38/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - cc: nan - loss: 0.0394 - root_mean_squared_error: 0.2814 - val_cc: nan - val_loss: 0.0270 - val_root_mean_squared_error: 0.2326
# Epoch 39/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - cc: nan - loss: 0.0391 - root_mean_squared_error: 0.2802 - val_cc: nan - val_loss: 0.0294 - val_root_mean_squared_error: 0.2423
# Epoch 40/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 19s 8ms/step - cc: nan - loss: 0.0395 - root_mean_squared_error: 0.2818 - val_cc: nan - val_loss: 0.0267 - val_root_mean_squared_error: 0.2311
# Epoch 41/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - cc: nan - loss: 0.0392 - root_mean_squared_error: 0.2808 - val_cc: nan - val_loss: 0.0272 - val_root_mean_squared_error: 0.2333
# Epoch 42/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 19s 8ms/step - cc: nan - loss: 0.0392 - root_mean_squared_error: 0.2806 - val_cc: nan - val_loss: 0.0350 - val_root_mean_squared_error: 0.2646
# Epoch 43/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - cc: nan - loss: 0.0382 - root_mean_squared_error: 0.2774 - val_cc: nan - val_loss: 0.0279 - val_root_mean_squared_error: 0.2363
# Epoch 44/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - cc: nan - loss: 0.0387 - root_mean_squared_error: 0.2787 - val_cc: nan - val_loss: 0.0271 - val_root_mean_squared_error: 0.2326
# Epoch 45/50
# 2108/2108 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - cc: nan - loss: 0.0381 - root_mean_squared_error: 0.2763 - val_cc: nan - val_loss: 0.0268 - val_root_mean_squared_error: 0.2316
# Epoch 45: early stopping
# Restoring model weights from the end of the best epoch: 40.

# %%
from tensorflow.keras.utils import plot_model
plt.figure(figsize=(5, 5))
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# Plot the training and validation metrics
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['root_mean_squared_error'], label='Training RMSE')
plt.plot(history.history['val_root_mean_squared_error'], label='Validation RMSE')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
# Evaluate the model on the test set
test_loss, test_rmse, test_cc = model.evaluate(X_test, y_test)

# Make predictions on the test set
y_pred = model.predict(X_test)
# Out:
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - cc: 0.6735 - loss: 0.0128 - root_mean_squared_error: 0.1587
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %%
# Plot the predicted and true labels
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5))
plt.plot(y_test, label='True Labels')
plt.plot(y_pred, label='Predicted Labels')
plt.legend()
plt.show()

# %%
#Step 9
#Evaluate the model on the 10, 100, 356 Days to Forecast
X_ten   = X_test[:10]
X_hundred = X_test[:100]
X_year = X_test[:365]

y_ten   = y_test[:10]
y_hundred = y_test[:100]
y_year = y_test[:365]

print("10 Day to Forecast")
test_loss, test_rmse, test_cc = model.evaluate(X_ten, y_ten)
y_pred_ten = model.predict(X_ten)


print("100 Days to Forecast")
test_loss, test_rmse, test_cc = model.evaluate(X_hundred, y_hundred)
y_pred_hundred = model.predict(X_hundred)

print("365 Days to Forecast")
test_loss, test_rmse, test_cc = model.evaluate(X_year, y_year)
y_pred_year = model.predict(X_year)
# Out:
# 10 Day to Forecast
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - cc: 0.7689 - loss: 0.0347 - root_mean_squared_error: 0.2635
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 100 Days to Forecast
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - cc: 0.8415 - loss: 0.0233 - root_mean_squared_error: 0.2156
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 365 Days to Forecast
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - cc: 0.8157 - loss: 0.0196 - root_mean_squared_error: 0.1975
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
#Step 10
#Inverse from scaled data
inv_pred_ten = scaler.inverse_transform(y_pred_ten)
inv_ten      = scaler.inverse_transform(y_ten)

inv_pred_hundred = scaler.inverse_transform(y_pred_hundred)
inv_hundred      = scaler.inverse_transform(y_hundred)

inv_pred_year = scaler.inverse_transform(y_pred_year)
inv_year     = scaler.inverse_transform(y_year)

#Copy data date
viz_ten   = ten_day_date.copy()
viz_hundred = hundred_day_date.copy()
viz_year = one_year_date.copy()

#Join true and predicted data
viz_ten['sn_pred'] = inv_pred_ten
viz_ten['sn_true'] = inv_ten

viz_hundred['sn_pred'] = inv_pred_hundred
viz_hundred['sn_true'] = inv_hundred

viz_year['sn_pred'] = inv_pred_year
viz_year['sn_true'] = inv_year

# %%
#10 Day Forecasting

# Load dataset
viz_ten = viz_ten.set_index('Date')

# Plot two columns in one chart
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(viz_ten.index, viz_ten['sn_pred'], label='Predicted')
ax.plot(viz_ten.index, viz_ten['sn_true'], label='True Label')

# Add labels and legend
ax.set_xlabel('Date')
ax.set_ylabel('SN')
ax.set_title('10 Day Forecasting')
ax.legend()

# Show plot
plt.show()

# %%
#100 Days Forecasting

# Load dataset
viz_hundred = viz_hundred.set_index('Date')

# Plot two columns in one chart
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(viz_hundred.index, viz_hundred['sn_pred'], label='Predicted')
ax.plot(viz_hundred.index, viz_hundred['sn_true'], label='True Label')

# Add labels and legend
ax.set_xlabel('Date')
ax.set_ylabel('SN')
ax.set_title('100 Day Forecasting')
ax.legend()

# Show plot
plt.show()

# %%
#365 Days Forecasting

# Load dataset
viz_year = viz_year.set_index('Date')

# Plot two columns in one chart
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(viz_year.index, viz_year['sn_pred'], label='Predicted')
ax.plot(viz_year.index, viz_year['sn_true'], label='True Label')

# Add labels and legend
ax.set_xlabel('Date')
ax.set_ylabel('SN')
ax.set_title('365 Day Forecasting')
ax.legend()

# Show plot
plt.show()

# %%
import pickle

# Save the trained model
model.save('/content/drive/MyDrive/Model/CNN-BiLSTM_Model_Final.h5')

# Save the history object
with open('/content/drive/MyDrive/Model/CNN-BiLSTM_history_Final.pkl', 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
#Use Model To Forecasting
#Load Library, Model, and Addition First

# %%
#1. Merge array data for base predict
x_data = np.vstack((X_train, X_val, X_test))
x_data
# Out:
# array([[[-0.95079432],
#         [-0.95079432],
#         [-1.03742334],
#         ...,
#         [-1.07207495],
#         [-1.07207495],
#         [-1.07207495]],
#
#        [[-0.95079432],
#         [-1.03742334],
#         [-1.07207495],
#         ...,
#         [-1.07207495],
#         [-1.07207495],
#         [-1.07207495]],
#
#        [[-1.03742334],
#         [-1.07207495],
#         [-1.07207495],
#         ...,
#         [-1.07207495],
#         [-1.07207495],
#         [-0.84683949]],
#
#        ...,
#
#        [[-0.18845891],
#         [-0.39636856],
#         [-0.50032339],
#         ...,
#         [-0.46567178],
#         [-0.91614271],
#         [-0.93346851]],
#
#        [[-0.39636856],
#         [-0.50032339],
#         [-0.24043632],
#         ...,
#         [-0.91614271],
#         [-0.93346851],
#         [-0.69090724]],
#
#        [[-0.50032339],
#         [-0.24043632],
#         [-0.24043632],
#         ...,
#         [-0.93346851],
#         [-0.69090724],
#         [-0.74288466]]])

# %%
#2. test model prediction
import numpy as np

# Set the window size and n_steps
n_steps = 100 # 100 days

# Get the last window_size data points
start_index = len(x_data) - n_steps
n_step = x_data[start_index:]

# Make the predictions
y_pred = model.predict(n_step)

# Print the predicted values
print(y_pred)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [[-0.20611662]
#  [-0.2528633 ]
#  [-0.44941393]
#  [-0.5180992 ]
#  [-0.5177866 ]
#  [-0.7427415 ]
#  [-0.7512232 ]
#  [-0.6884538 ]
#  [-0.35816354]
#  [-0.27483737]
#  [-0.2880181 ]
#  [-0.39958292]
#  [-0.53460866]
#  [-0.6893942 ]
#  [-0.70280045]
#  [-0.7753028 ]
#  [-0.76562595]
#  [-0.7148765 ]
#  [-0.7181448 ]
#  [-0.65681994]
#  [-0.42314753]
#  [-0.24998462]
#  [-0.22693063]
#  [-0.27971175]
#  [-0.38810146]
#  [-0.5034192 ]
#  [-0.53313243]
#  [-0.5029628 ]
#  [-0.7086261 ]
#  [-0.72452694]
#  [-0.63697076]
#  [ 0.00961043]
#  [ 0.24315983]
#  [ 0.29526317]
#  [ 0.27396467]
#  [ 0.20182216]
#  [ 0.02201886]
#  [-0.19162272]
#  [-0.3789007 ]
#  [-0.54533565]
#  [-0.5383648 ]
#  [-0.56935626]
#  [-0.60349894]
#  [-0.56630766]
#  [-0.29368615]
#  [-0.30221277]
#  [-0.2984445 ]
#  [-0.40019464]
#  [-0.4314097 ]
#  [-0.4816361 ]
#  [-0.48017347]
#  [-0.221795  ]
#  [ 0.16711429]
#  [ 0.23712385]
#  [ 0.2509958 ]
#  [ 0.17299893]
#  [ 0.2953266 ]
#  [ 0.5439272 ]
#  [ 0.51948744]
#  [ 0.5317726 ]
#  [ 0.3983661 ]
#  [ 0.57044685]
#  [ 0.57054496]
#  [ 0.14214045]
#  [-0.19556782]
#  [-0.23467398]
#  [-0.4090847 ]
#  [-0.4471403 ]
#  [-0.6384324 ]
#  [-0.7465077 ]
#  [-0.75601995]
#  [-0.7400548 ]
#  [-0.6198028 ]
#  [-0.40674472]
#  [ 0.16951111]
#  [ 0.35191798]
#  [ 0.5865255 ]
#  [ 0.6625553 ]
#  [ 0.5827193 ]
#  [ 0.6681093 ]
#  [ 0.6449608 ]
#  [ 0.6938796 ]
#  [ 0.7110111 ]
#  [ 0.70607686]
#  [ 0.6575247 ]
#  [ 0.2001833 ]
#  [-0.01642652]
#  [-0.04132836]
#  [-0.11605699]
#  [-0.2788326 ]
#  [-0.3602568 ]
#  [-0.3388111 ]
#  [-0.1428917 ]
#  [-0.15926811]
#  [-0.1835723 ]
#  [-0.3215899 ]
#  [-0.7465796 ]
#  [-0.81127894]
#  [-0.83316684]
#  [-0.70600915]]

# %%
#3. Invers to original data
inv_data = scaler.inverse_transform(y_pred)
inv_data
# Out:
# array([[ 49.980843],
#        [ 47.28275 ],
#        [ 35.938362],
#        [ 31.974028],
#        [ 31.992067],
#        [ 19.008263],
#        [ 18.518723],
#        [ 22.141605],
#        [ 41.205093],
#        [ 46.01446 ],
#        [ 45.253704],
#        [ 38.814476],
#        [ 31.021145],
#        [ 22.08733 ],
#        [ 21.313557],
#        [ 17.12891 ],
#        [ 17.687431],
#        [ 20.616558],
#        [ 20.427921],
#        [ 23.96743 ],
#        [ 37.454388],
#        [ 47.4489  ],
#        [ 48.779514],
#        [ 45.733128],
#        [ 39.477158],
#        [ 32.82132 ],
#        [ 31.106348],
#        [ 32.84766 ],
#        [ 20.977314],
#        [ 20.059559],
#        [ 25.113071],
#        [ 62.43204 ],
#        [ 75.9119  ],
#        [ 78.91917 ],
#        [ 77.68987 ],
#        [ 73.526   ],
#        [ 63.148224],
#        [ 50.817394],
#        [ 40.0082  ],
#        [ 30.40201 ],
#        [ 30.804348],
#        [ 29.015602],
#        [ 27.04498 ],
#        [ 29.191563],
#        [ 44.92656 ],
#        [ 44.434425],
#        [ 44.65192 ],
#        [ 38.77917 ],
#        [ 36.97752 ],
#        [ 34.078583],
#        [ 34.163002],
#        [ 49.075928],
#        [ 71.52275 ],
#        [ 75.56352 ],
#        [ 76.364174],
#        [ 71.8624  ],
#        [ 78.92283 ],
#        [ 93.27141 ],
#        [ 91.86081 ],
#        [ 92.56988 ],
#        [ 84.87    ],
#        [ 94.80205 ],
#        [ 94.80772 ],
#        [ 70.08133 ],
#        [ 50.58969 ],
#        [ 48.33259 ],
#        [ 38.26606 ],
#        [ 36.069588],
#        [ 25.02871 ],
#        [ 18.790886],
#        [ 18.241867],
#        [ 19.163334],
#        [ 26.103962],
#        [ 38.401115],
#        [ 71.66109 ],
#        [ 82.18914 ],
#        [ 95.73007 ],
#        [100.11831 ],
#        [ 95.51038 ],
#        [100.43887 ],
#        [ 99.1028  ],
#        [101.92627 ],
#        [102.915054],
#        [102.63026 ],
#        [ 99.82796 ],
#        [ 73.43141 ],
#        [ 60.929256],
#        [ 59.49199 ],
#        [ 55.17885 ],
#        [ 45.783867],
#        [ 41.08428 ],
#        [ 42.322067],
#        [ 53.63002 ],
#        [ 52.68482 ],
#        [ 51.282043],
#        [ 43.31603 ],
#        [ 18.78674 ],
#        [ 15.05246 ],
#        [ 13.78915 ],
#        [ 21.128357]], dtype=float32)

# %%
#4. Copy Dataframe
viz = df_sn.copy()
viz
# Out:
#             Date  Sn
# 0     1900-01-01   7
# 1     1900-01-02   7
# 2     1900-01-03   2
# 3     1900-01-04   0
# 4     1900-01-05   0
# ...          ...  ..
# 42149 2015-05-27   9
# 42150 2015-05-28   8
# 42151 2015-05-29  22
# 42152 2015-05-30  19
# 42153 2015-05-31  17
#
# [42154 rows x 2 columns]

# %%
#5. Generate new forecasting date
from prophet import Prophet
m = Prophet()

viz = viz.rename(columns={'Date': 'ds', 'Sn' : 'y'})

m.fit(viz)
future = m.make_future_dataframe(periods=n_steps, freq='D', include_history=False)
future
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp9mymglep/tl7a5vxf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp9mymglep/hu1_b5oi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=49547', 'data', 'file=/tmp/tmp9mymglep/tl7a5vxf.json', 'init=/tmp/tmp9mymglep/hu1_b5oi.json', 'output', 'file=/tmp/tmp9mymglep/prophet_modelflm70tf2/prophet_model-20240827115503.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:55:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:55:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#            ds
# 0  2015-06-01
# 1  2015-06-02
# 2  2015-06-03
# 3  2015-06-04
# 4  2015-06-05
# ..        ...
# 95 2015-09-04
# 96 2015-09-05
# 97 2015-09-06
# 98 2015-09-07
# 99 2015-09-08
#
# [100 rows x 1 columns]

# %%
#6. Merge Forecasting Date and Data
future['Sn'] = inv_data
future = future.rename(columns={'ds': 'Date'})
future
# Out:
#          Date         Sn
# 0  2015-06-01  49.980843
# 1  2015-06-02  47.282749
# 2  2015-06-03  35.938362
# 3  2015-06-04  31.974028
# 4  2015-06-05  31.992067
# ..        ...        ...
# 95 2015-09-04  43.316029
# 96 2015-09-05  18.786739
# 97 2015-09-06  15.052460
# 98 2015-09-07  13.789150
# 99 2015-09-08  21.128357
#
# [100 rows x 2 columns]

# %%
#7. Copy historical data for Visualization
history_predict = n_steps #Set by window_size, 100 days

hist_data = df_sn.copy()
hist_data

start_index = len(hist_data) - history_predict
hist_data = hist_data[start_index:]

# %%
#8. Set Index
hist_data = hist_data.set_index('Date')
future_data = future.set_index('Date')

# %%
#9. Visualization

import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(15, 5))
hist_data.plot(ax=ax, label='Training Data', title='Observed Data')
future_data.plot(ax=ax, label='Predicted')
ax.axvline('2015-06-01', color='black', ls='--')
ax.legend(['Training Set', 'Predicted'])
plt.show()
